# %%
import numpy as np
from bokeh.plotting import output_notebook, figure, show

# %%
x=np.linspace(-2, 2, 4000)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
y1=np.sin(x)

# %%
y2=np.cos(x)

# %%
y3=np.exp(x)

# %%
y4=np.square(x) - 4

# %%
#p=figure(width=500)
p=figure()

# %%
#p.circle(x, y,size=2,  legend="sin(x)")
p.line(x, y1, legend="sin(x)")

# %%
p.line(x, y2, legend="cos(x)", line_color='orange')

# %%
p.line(x, y3, legend="exp(x)", line_color='purple')

# %%
p.line(x, y4, line_color="red", legend="y = x*x - 4")

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ae9c352d-dd3e-41ba-a384-4d08a1ac8bd0">Loading BokehJS ...</span>
#     </div>

# %%
show(p)
# Out:
#     <div class="plotdiv" id="ac8fdd8a-3017-4e80-bea5-395c3d28264c"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ac8fdd8a-3017-4e80-bea5-395c3d28264c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ac8fdd8a-3017-4e80-bea5-395c3d28264c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3b2e2522-b78a-425e-b0b3-d4c17c332ae3":{"roots":{"references":[{"attributes":{"plot":{"id":"087013a4-ba19-4205-9942-cdeb5cb9cada","subtype":"Figure","type":"Plot"}},"id":"c7fdc3d8-ae55-45d7-9b6e-32b3c09c578a","type":"PreviewSaveTool"},{"attributes":{"callback":null},"id":"f4146829-9640-4656-a1bf-134645b39fd1","type":"DataRange1d"},{"attributes":{"data_source":{"id":"33b8850f-028b-4c07-b742-9a8c5767463a","type":"ColumnDataSource"},"glyph":{"id":"193e69d6-513a-4076-9347-4a8ae338fc5d","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"9e00fe51-38ce-44df-a225-a10eb913f45f","type":"Line"},"selection_glyph":null},"id":"a7769563-721a-4c08-827c-65ba52495230","type":"GlyphRenderer"},{"attributes":{},"id":"e4ef0d45-4aa1-4ab3-8d76-bfe4a9a95e0f","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e6fae4e3-f98d-4c15-a8e9-ce10270f98b6","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[-2.0,-1.9989997499374843,-1.9979994998749688,-1.9969992498124531,-1.9959989997499374,-1.9949987496874217,-1.9939984996249063,-1.9929982495623906,-1.9919979994998749,-1.9909977494373594,-1.9899974993748437,-1.988997249312328,-1.9879969992498125,-1.9869967491872969,-1.9859964991247812,-1.9849962490622655,-1.98399599899975,-1.9829957489372343,-1.9819954988747186,-1.9809952488122031,-1.9799949987496874,-1.9789947486871717,-1.9779944986246563,-1.9769942485621406,-1.9759939984996249,-1.9749937484371092,-1.9739934983745937,-1.972993248312078,-1.9719929982495623,-1.9709927481870468,-1.9699924981245311,-1.9689922480620154,-1.9679919979995,-1.9669917479369843,-1.9659914978744686,-1.964991247811953,-1.9639909977494374,-1.9629907476869217,-1.961990497624406,-1.9609902475618906,-1.9599899974993749,-1.9589897474368592,-1.9579894973743435,-1.956989247311828,-1.9559889972493123,-1.9549887471867966,-1.9539884971242811,-1.9529882470617654,-1.9519879969992497,-1.9509877469367343,-1.9499874968742186,-1.9489872468117029,-1.9479869967491874,-1.9469867466866717,-1.945986496624156,-1.9449862465616403,-1.9439859964991248,-1.9429857464366092,-1.9419854963740935,-1.940985246311578,-1.9399849962490623,-1.9389847461865466,-1.937984496124031,-1.9369842460615154,-1.9359839959989997,-1.934983745936484,-1.9339834958739686,-1.9329832458114529,-1.9319829957489372,-1.9309827456864217,-1.929982495623906,-1.9289822455613903,-1.9279819954988746,-1.9269817454363591,-1.9259814953738434,-1.9249812453113277,-1.9239809952488123,-1.9229807451862966,-1.9219804951237809,-1.9209802450612652,-1.9199799949987497,-1.918979744936234,-1.9179794948737183,-1.9169792448112029,-1.9159789947486872,-1.9149787446861715,-1.913978494623656,-1.9129782445611403,-1.9119779944986246,-1.9109777444361091,-1.9099774943735934,-1.9089772443110777,-1.907976994248562,-1.9069767441860466,-1.9059764941235309,-1.9049762440610152,-1.9039759939984997,-1.902975743935984,-1.9019754938734683,-1.9009752438109526,-1.8999749937484371,-1.8989747436859215,-1.8979744936234058,-1.8969742435608903,-1.8959739934983746,-1.894973743435859,-1.8939734933733434,-1.8929732433108277,-1.891972993248312,-1.8909727431857963,-1.8899724931232809,-1.8889722430607652,-1.8879719929982495,-1.886971742935734,-1.8859714928732183,-1.8849712428107026,-1.8839709927481871,-1.8829707426856714,-1.8819704926231557,-1.88097024256064,-1.8799699924981246,-1.8789697424356089,-1.8779694923730932,-1.8769692423105777,-1.875968992248062,-1.8749687421855463,-1.8739684921230308,-1.8729682420605152,-1.8719679919979995,-1.8709677419354838,-1.8699674918729683,-1.8689672418104526,-1.867966991747937,-1.8669667416854214,-1.8659664916229057,-1.86496624156039,-1.8639659914978743,-1.8629657414353589,-1.8619654913728432,-1.8609652413103275,-1.859964991247812,-1.8589647411852963,-1.8579644911227806,-1.8569642410602651,-1.8559639909977494,-1.8549637409352338,-1.8539634908727183,-1.8529632408102026,-1.8519629907476869,-1.850962740685171 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[33]</strong>&gt;</code></p>

# %%
import math

# %%
math.sqrt(9)
# Out:
# 3.0

# %%
np.sqrt(9)
# Out:
# 3.0

# %% [markdown]
# $ y = x^2 -4 $

# %%
q=[1, 0, -4]

# %%
type(q)
# Out:
# list

# %%
my_solution=np.roots(q)

# %%
type(my_solution)
# Out:
# numpy.ndarray

# %%
print(my_solution)
# Out:
# [ 2. -2.]

# %%
from sympy import *
x= Symbol('x')

# %%
limit(sin(x)/x, x, 0 )
# Out:
# 1

# %%
integrate(1/x,x)
# Out:
# log(x)

# %%
np.pi
# Out:
# 3.141592653589793

# %% [markdown]
# from matplotlib import *
# plt.title('alpha > beta')

# %% [markdown]
# ## The basic linear algebra with N = 2
#
# You can think of a vector - a list of numbers - as coefficients times basis vectors.
#
# $$  f_0 \left[ \begin{array}{c}  1 \\ 0  \end{array} \right] + f_1 \left[ \begin{array}{c}  0 \\ 1  \end{array} \right] $$

# %% [markdown]
# $e^{i\pi} + 1 = 0$

# %% [markdown]
# $ \left ( f_0 \left [ x \right] = 0 \right ) $   OR    $ \left ( f_0 \left(x \right) = \frac{1}{\sqrt{2}} \right ) $
